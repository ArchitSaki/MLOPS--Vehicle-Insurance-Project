# %%
import pandas as pd
import pymongo

# %%
df=pd.read_csv('data (2).csv')

# %%
data = df.to_dict(orient='records')

# %%
DB_name="project_1"
Collection_name="project_vehicle"
collection_url="mongodb+srv://itsarchitsaki_db_user:nDzplvZKDLnEXOFa@cluster0.ju2khuw.mongodb.net/?appName=Cluster0"

# %%
client=pymongo.MongoClient(collection_url)
data_base=client[DB_name]
collection=data_base[Collection_name]

# %%
rec = collection.insert_many(data)
